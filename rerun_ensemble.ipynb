# %%
import os
import json
import torch
from termcolor import cprint

# %%
def summary_stats(nums):
    total = sum(nums)
    mean = total / len(nums)

    variance = sum([(mean - x)**2 for x in nums]) / (len(nums) - 1)
    return mean, variance ** 0.5

# %%
grid_vals = [0, 2.5e-5, 2.5e-4, 2.5e-3, 2.5e-2, 2.5e-1, 2.5, 25]

winners = []

for name in sorted(os.listdir("grid_search_weight_decay")):
    if name[0] == ".": continue# or not name.startswith("fastvit_ma36"): continue

    print(name)
    
    path = f"grid_search_weight_decay/{name}"
    aucs_path = path + "/objects/curve_and_auc_sigmoid/"

    names = []
    means = []
    stds = []

    zero_path = f"weight_decay_zero/{name}/objects/curve_and_auc_sigmoid/0-fold_roc_auc.pth"
    data = torch.load(zero_path, weights_only=False)

    mean, std = summary_stats([o["auc"] for o in data])
    names.append("zero_manual")
    means.append(mean)
    stds.append(std)
    
    for i, filename in enumerate(sorted(os.listdir(aucs_path)), start=1):
        auc_path = aucs_path + filename
        data = torch.load(auc_path, weights_only=False)
        mean, std = summary_stats([ o["auc"] for o in data])

        names.append(filename)
        means.append(mean)
        stds.append(std)

    large_path = f"weight_decay_large/{name}/objects/curve_and_auc_sigmoid/0-fold_roc_auc.pth"
    data = torch.load(large_path, weights_only=False)

    mean, std = summary_stats([o["auc"] for o in data])
    names.append("large_manual")
    means.append(mean)
    stds.append(std)

    large_path = f"weight_decay_larger/{name}/objects/curve_and_auc_sigmoid/0-fold_roc_auc.pth"
    data = torch.load(large_path, weights_only=False)

    mean, std = summary_stats([o["auc"] for o in data])
    names.append("larger_manual")
    means.append(mean)
    stds.append(std)

    mean_sorted = sorted(means)
    std_sorted = sorted(stds)

    winner = None

    for i in range(len(names)):
        print(grid_vals[i], end="\t\t")

        if means[i] == mean_sorted[-1]:
            cprint(means[i], "green", end="\t")
            if winner is None:
                zero_path = f"weight_decay_zero/{name}/objects/logits/0-fold-logits.pth"
                decay_path = f"grid_search_weight_decay/{name}/objects/{i-1}-fold-logits.pth"
                large_path = f"weight_decay_large/{name}/objects/logits/0-fold-logits.pth"

                winner = {
                    "grid_idx": i,
                    "name": name,
                    "weight_decay": grid_vals[i],
                    "mean": means[i].item(),
                    "std": stds[i].item(),
                    "logits": zero_path if i == 0 else large_path if i == 6 else decay_path
                }
        elif means[i] == mean_sorted[-2]:
            cprint(means[i], "yellow", end="\t")
        else:
            print(means[i], end="\t")
            
        if stds[i] == std_sorted[0]:
            cprint(stds[i], "green")
        else:
            print(stds[i])

    winners.append(winner)

    print("-"*65)
# Out:
# convnextv2_nano
# 0		0.7919452361913424	0.06448426577221046
# 2.5e-05		0.7919452361913424	0.06448426577221046
# 0.00025		0.7919452361913424	0.06448426577221046
# 0.0025		0.7444748604863073	0.08324993640520821
# 0.025		0.8198331823097258	0.12292141694976638
# 0.25		0.7484067150280324	0.03654219841695557
# 2.5		0.8381306010457822	0.09031020512304658
# 25		0.5	0.0
# -----------------------------------------------------------------
# convnextv2_tiny
# 0		0.6533936392293965	0.12789297710637568
# 0.00025		0.9290189255684659	0.03455340982011543
# 0.0025		0.942055791952583	0.014846828916996065
# 0.025		0.9376750155109134	0.019144476595832155
# 0.25		0.9422241790486302	0.01122212009100446
# 2.5		0.940902412545779	0.03836787004320232
# 25		0.7683440571365134	0.057959355441909166
# -----------------------------------------------------------------
# repvit_m3.native
# 0		0.9380047809115177	0.012904727928650375
# 2.5e-05		0.9380047809115177	0.012904727928650375
# 0.00025		0.9380047809115177	0.012904727928650375
# 0.0025		0.9381396455566093	0.025295596033344688
# 0.025		0.9411542430026199	0.023158072781818563
# 0.25		0.9407737959389302	0.020982209869237767
# 2.5		0.9476100866300715	0.03009761784007254
# 25		0.6931409430635364	0.12692902933591574
# -----------------------------------------------------------------
# resnetv2_18
# 0		0.9251410774632767	0.030709099855354784
# 2.5e-05		0.9251410774632767	0.030709099855354784
# 0.00025		0.9251410774632767	0.030709099855354784
# 0.0025		0.927066487579717	0.03208341309991824
# 0.025		0.9325750666222611	0.02962745871810085
# 0.25		0.9491805349166016	0.011323122512539372
# 2.5		0.9107116170401965	0.06272057305893035
# 25		0.7470067881730482	0.10854383724026222
# -----------------------------------------------------------------
# resnetv2_34
# 0		0.9531948325694808	0.01930088566628198
# 2.5e-05		0.9531948325694808	0.01930088566628198
# 0.00025		0.9531948325694808	0.01930088566628198
# 0.0025		0.9415035907553266	0.022498710664244782
# 0.025		0.9557280915744043	0.012955302404596292
# 0.25		0.9594601004645102	0.012543259616131789
# 2.5		0.8333280186266206	0.19299497172844443
# 25		0.6428435308079706	0.11000433773758184
# -----------------------------------------------------------------

# %%
with open("grid_winners.json", "w") as file:
    json.dump(winners, file)

# %% [markdown]
# # Sanity Check AUC of a particular fold

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
import timm
import json
import torch.utils.data
from load_dataset import make_dataset

# %%
with open(base_path + f"{GRID_IDX}-dataset_settings.json", "r") as file:
    dataset_settings = json.loads(file.read())

BASE_DIR = "./data"
IMAGE_DIR = "./data/images"

dataset = make_dataset(BASE_DIR, IMAGE_DIR, 
                       image_size=(224, 224),
                       label_map=dataset_settings["label_map"])

# %%
RUN = "grid_search_weight_decay"
MODEL = "resnetv2_34"
MODEL_NAME = "resnetv2_34"
GRID_IDX = 4
FOLD_IDX = 4

# %%
base_path = f"{RUN}/{MODEL}/objects/"
checkpoint = base_path + f"checkpoints/{GRID_IDX}-fold-{FOLD_IDX}-state.pth"

weights = torch.load(checkpoint)

# %%
model = timm.create_model(MODEL_NAME, num_classes=1)
model.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
test_indices = torch.load(base_path + f"indices/{GRID_IDX}_fold_{FOLD_IDX}_test_indices.arr", weights_only=False)
test_subset = torch.utils.data.Subset(dataset, test_indices)

test_loader = torch.utils.data.DataLoader(test_subset, batch_size = 2048, shuffle=False)

# %%
model.to("cuda:1")
model.eval()

with torch.no_grad():
    y_true = []
    y_scores = []
    
    for inputs, labels in test_loader:
        inputs = inputs.type(torch.float).to("cuda:1")
        labels = labels.type(torch.float).to("cuda:1")
    
        output = torch.sigmoid(model(inputs)).reshape(-1)
        output = model(inputs).reshape(-1)
    
        y_scores.extend(output.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

y_true = np.array(y_true).flatten()
y_scores = np.array(y_scores).flatten()

# %%
fpr, tpr, _ = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)
print("AUC:", roc_auc)
sums.append(roc_auc)
# Out:
# AUC: 0.96996996996997

# %%
sum(sums)/5
# Out:
# 0.9594601004645102

# %% [markdown]
# # Recalc AUCs with Sigmoid
# Found that there are actually some differences using raw logits and sigmoid because of floating point truncation

# %%
from sklearn.metrics import roc_curve, auc

# %%
def metric_dict(y_true, y_logits):
    y_scores = torch.sigmoid(torch.from_numpy(y_logits))
    
    fpr, tpr, _ = roc_curve(y_true, y_scores)
    auc_val = auc(fpr, tpr)

    return { "fpr": fpr, "tpr": tpr, "auc": auc_val }

# %%
RUNS = "weight_decay_larger"

for name in sorted(os.listdir(RUNS)):
    if name[0] == ".":
        continue

    all_logits_path = f"{RUNS}/{name}/objects/logits/"
    all_aucs_path = f"{RUNS}/{name}/objects/curve_and_auc/"

    output_path = f"{RUNS}/{name}/objects/curve_and_auc_sigmoid/"

    os.makedirs(output_path, exist_ok=True)

    for logits_path, aucs_path in zip(sorted(os.listdir(all_logits_path)), sorted(os.listdir(all_aucs_path))):
        grid_logits = torch.load(os.path.join(all_logits_path, logits_path), weights_only=False)
        grid_aucs = torch.load(os.path.join(all_aucs_path, aucs_path), weights_only=False)

        metrics = [metric_dict(*numbers) for numbers in grid_logits]

        print(metrics)

        torch.save(metrics, os.path.join(output_path, aucs_path))
# Out:
# [{'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}]
# [{'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}]
# [{'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}]
# [{'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}]
# [{'fpr': array([0.        , 0.        , 0.        , 0.01351351, 0.01351351,
#        0.02702703, 0.02702703, 0.04054054, 0.04054054, 0.06756757,
#        0.06756757, 0.09459459, 0.09459459, 0.10810811, 0.10810811,
#        0.12162162, 0.12162162, 0.13513514, 0.13513514, 0.16216216,
#        0.16216216, 0.2027027 , 0.2027027 , 0.28378378, 0.28378378,
#        0.36486486, 0.36486486, 0.41891892, 0.41891892, 0.58108108,
#        0.58108108, 0.64864865, 0.64864865, 0.7027027 , 0.7027027 ,
#        0.75675676, 0.75675676, 0.83783784, 0.83783784, 0.89189189,
#        0.89189189, 0.95945946, 0.95945946, 0.98648649, 0.98648649,
#        1.        ]), 'tpr': array([0.        , 0.01369863, 0.04109589, 0.04109589, 0.23287671,
#        0.23287671, 0.28767123, 0.28767123, 0.53424658, 0.53424658,
#        0.56164384, 0.56164384, 0.60273973, 0.60273973, 0.65753425,
#        0.65753425, 0.67123288, 0.67123288, 0.68493151, 0.68493151,
#        0.78082192, 0.78082192, 0.79452055, 0.79452055, 0.82191781,
#        0.82191781, 0.83561644, 0.83561644, 0.84931507, 0.84931507,
#        0.8630137 , 0.8630137 , 0.87671233, 0.87671233, 0.89041096,
#        0.89041096, 0.93150685, 0.93150685, 0.94520548, 0.94520548,
#        0.95890411, 0.95890411, 0.98630137, 0.98630137, 1.        ,
#        1.        ]), 'auc': np.float64(0.8128470936690114)}, {'fpr': array([0.        , 0.        , 0.        , 0.01351351, 0.01351351,
#        0.02702703, 0.02702703, 0.04054054, 0.04054054, 0
#        0.73972603, 0.76712329, 0.76712329, 0.78082192, 0.78082192,
#        0.79452055, 0.79452055, 0.80821918, 0.80821918, 0.83561644,
#        0.83561644, 0.84931507, 0.84931507, 0.8630137 , 0.8630137 ,
#        0.87671233, 0.87671233, 0.89041096, 0.89041096, 0.91780822,
#        0.91780822, 0.93150685, 0.93150685, 0.94520548, 0.94520548,
#        0.97260274, 0.97260274, 0.98630137, 0.98630137, 1.        ,
#        1.        ]), 'auc': np.float64(0.759163272861903)}, {'fpr': array([0.        , 0.77027027, 0.77027027, 0.7972973 , 0.7972973 ,
#        0.82432432, 0.82432432, 0.95945946, 1.        ]), 'tpr': array([0.        , 0.94520548, 0.97260274, 0.97260274, 0.98630137,
#        0.98630137, 1.        , 1.        , 1.        ]), 'auc': np.float64(0.5926508700481303)}, {'fpr': array([0.        , 0.68493151, 0.7260274 , 0.79452055, 0.79452055,
#        0.83561644, 0.83561644, 0.89041096, 0.89041096, 0.93150685,
#        0.93150685, 1.        ]), 'tpr': array([0.        , 0.90410959, 0.94520548, 0.94520548, 0.95890411,
#        0.95890411, 0.97260274, 0.97260274, 0.98630137, 0.98630137,
#        1.        , 1.        ]), 'auc': np.float64(0.6140927003190093)}, {'fpr': array([0., 1.]), 'tpr': array([0., 1.]), 'auc': np.float64(0.5)}, {'fpr': array([0.        , 0.        , 0.        , 0.01351351, 0.01351351,
#        0.04054054, 0.04054054, 0.05405405, 0.05405405, 0.06756757,
#        0.06756757, 0.08108108, 0.08108108, 0.40540541, 0.41891892,
#        0.41891892, 0.51351351, 0.51351351, 0.52702703, 0.52702703,
#        0.62162162, 0.62162162, 0.64864865, 0.64864865, 0.72972973,
#        0.72972973, 0.75675676, 0.75675676, 0.81081081, 0.81081081,
#        0.83783784, 0.83783784, 0.85135135, 0.85135135, 0.86486486,
#        0.86486486, 0.91891892, 0.91891892, 0.94594595, 0.94594595,
#        1.        , 1.        ]), 'tpr': array([0.        , 0.01388889, 0.15277778, 0.15277778, 0.29166667,
#        0.29166667, 0.375     , 0.375     , 0.5       , 0.5       ,
#        0.51388889, 0.51388889, 0.52777778, 0.73611111, 0.73611111,
#        0.76388889, 0.76388889, 0.77777778, 0.77777778, 0.79166667,
#        0.79166667, 0.84722222, 0.84722222, 0.86111111, 0.86111111,
#        0.88888889, 0.88888889, 0.90277778, 0.90277778, 0.91666667,
#        0.91666667, 0.93055556, 0.93055556, 0.94444444, 0.94444444,
#        0.95833333, 0.95833333, 0.97222222, 0.97222222, 0.98611111,
#        0.98611111, 1.        ]), 'auc': np.float64(0.7483108108108107)}]

# %% [markdown]
# # Make the ensemble model!

# %%
with open("grid_winners.json", "r") as file:
    winners_data = json.load(file)

# %%
winners_data
# Out:
# [{'grid_idx': 4,
#   'name': 'convnextv2_nano',
#   'weight_decay': 0.025,
#   'mean': 0.8198331823097258,
#   'std': 0.12292141694976638,
#   'logits': 'grid_search_weight_decay/convnextv2_nano/objects/3-fold-logits.pth'},
#  {'grid_idx': 3,
#   'name': 'convnextv2_tiny',
#   'weight_decay': 0.0025,
#   'mean': 0.7679958998217582,
#   'std': 0.13168745378157093,
#   'logits': 'grid_search_weight_decay/convnextv2_tiny/objects/2-fold-logits.pth'},
#  {'grid_idx': 5,
#   'name': 'efficientnetv2_m',
#   'weight_decay': 0.25,
#   'mean': 0.95310707827362,
#   'std': 0.013609475777101143,
#   'logits': 'grid_search_weight_decay/efficientnetv2_m/objects/4-fold-logits.pth'},
#  {'grid_idx': 3,
#   'name': 'efficientnetv2_s',
#   'weight_decay': 0.0025,
#   'mean': 0.9339188527052104,
#   'std': 0.021599880284314095,
#   'logits': 'grid_search_weight_decay/efficientnetv2_s/objects/2-fold-logits.pth'},
#  {'grid_idx': 5,
#   'name': 'fastvit_ma36',
#   'weight_decay': 0.25,
#   'mean': 0.9758976817876237,
#   'std': 0.011613085407095344,
#   'logits': 'grid_search_weight_decay/fastvit_ma36/objects/4-fold-logits.pth'},
#  {'grid_idx': 0,
#   'name': 'fastvit_t8',
#   'weight_decay': 0,
#   'mean': 0.8810728219775414,
#   'std': 0.05036631191339412,
#   'logits': 'weight_decay_zero/fastvit_t8/objects/logits/0-fold-logits.pth'},
#  {'grid_idx': 3,
#   'name': 'mobilenetv4_conv_large',
#   'weight_decay': 0.0025,
#   'mean': 0.940769111671251,
#   'std': 0.02766517539356972,
#   'logits': 'grid_search_weight_decay/mobilenetv4_conv_large/objects/2-fold-logits.pth'},
#  {'grid_idx': 4,
#   'name': 'mobilenetv4_conv_medium',
#   'weight_decay': 0.025,
#   'mean': 0.9059460755557585,
#   'std': 0.03180304287301538,
#   'logits': 'grid_search_weight_decay/mobilenetv4_conv_medium/objects/3-fold-logits.pth'},
#  {'grid_idx': 5,
#   'name': 'repvit_m2.native',
#   'weight_decay': 0.25,
#   'mean': 0.9422241790486302,
#   'std': 0.01122212009100446,
#   'logits': 'grid_search_weight_decay/repvit_m2.native/objects/4-fold-logits.pth'},
#  {'grid_idx': 4,
#   'name': 'repvit_m3.native',
#   'weight_decay': 0.025,
#   'mean': 0.9411542430026199,
#   'std': 0.023158072781818563,
#   'logits': 'grid_search_weight_decay/repvit_m3.native/objects/3-fold-logits.pth'},
#  {'grid_idx': 5,
#   'name': 'resnetv2_18',
#   'weight_decay': 0.25,
#   'mean': 0.9491805349166016,
#   'std': 0.011323122512539372,
#   'logits': 'grid_search_weight_decay/resnetv2_18/objects/4-fold-logits.pth'},
#  {'grid_idx': 5,
#   'name': 'resnetv2_34',
#   'weight_decay': 0.25,
#   'mean': 0.9594601004645102,
#   'std': 0.012543259616131789,
#   'logits': 'grid_search_weight_decay/resnetv2_34/objects/4-fold-logits.pth'}]

# %%
for winner in winners_data:
    print(winner["name"])
# Out:
# convnextv2_nano
# convnextv2_tiny
# efficientnetv2_m
# efficientnetv2_s
# fastvit_ma36
# fastvit_t8
# mobilenetv4_conv_large
# mobilenetv4_conv_medium
# repvit_m2.native
# repvit_m3.native
# resnetv2_18
# resnetv2_34
